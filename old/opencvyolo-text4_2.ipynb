# %%
# Notes

# This version includes:

# capture interval, 
# confidence threshold, 
# capturing only different gestures (i.e., the current captured gesture must be different from the previous one).

# %%
# This code started as a direct copy from opencv
# https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html

import numpy as np
import cv2 as cv
import time

# Info about YOLO import and loading the Yolo Model
# https://docs.ultralytics.com/tasks/classify/#train

# Added this to import YOLO
from ultralytics import YOLO

# Load the YOLOv8 model, this is loading our custom-trained weights for our model.
model = YOLO("best_v2.pt")
 
cap = cv.VideoCapture(0)

captured_text = []
captured_confidence = []

last_captured = None

# Set up Confidence Threshold
confidence_threshold = 0.9  # Set a confidence threshold

# Set up Capture interval
capture_interval = 1  # Time in seconds between capturing gestures

# Initialize time for the capture interval
last_capture_time = time.time()  # Time of the last capture

if not cap.isOpened():
    print("Cannot open camera")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
 
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

   
    # Set the size of the video
   # ret = cap.set(cv.CAP_PROP_FRAME_WIDTH, 240)
   # ret = cap.set(cv.CAP_PROP_FRAME_HEIGHT, 240)
    
    # Convert the frame to grayscale
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    
    # Display the grayscale frame
    cv.imshow('frame', gray)
    
    # Run YOLOv8 inference on the frame
    results = model(frame)
    top_class = results[0].probs.top1  # Get the most confident prediction
    top_confidence = results[0].probs.top1conf  # Get confidence of the top-class prediction

    

    # Check the time interval and confidence threshold before capturing
    current_time = time.time()
    if current_time - last_capture_time >= capture_interval:
        # Only capture if confidence is greater than threshold and gesture is new
        if top_confidence >= confidence_threshold and top_class != last_captured:
            captured_text.append(top_class)
            captured_confidence.append(top_confidence)
            
            last_captured = top_class  # Update the last captured gesture
            last_capture_time = current_time  # Reset the capture time



    # Visualize the results on the frame
    annotated_frame = results[0].plot()

    # Display the annotated frame
    cv.imshow("YOLOv8 Inference", annotated_frame)

    # Exit when 'q' key is pressed
    if cv.waitKey(1) == ord('q'):
        print("Captured top class: ", captured_text)

        # ASCII reference to convert integer classes to text (A-Z, del, nothing, space)
        translated_text = []
        for i in captured_text:
            if i < 26:
                translated_text.append(chr(i + 65))  # A-Z
            elif i == 26:
                translated_text.append("del")
            elif i == 27:
                translated_text.append("nothing")
            elif i == 28:
                translated_text.append("space")
        
        print("Translated text: ", translated_text)
        print("Confidence: ", captured_confidence)
        break
        
# When everything is done, release the capture
cap.release()
cv.destroyAllWindows()
# Out:
# 0: 224x224 E 0.30, O 0.14, C 0.11, S 0.09, R 0.09, 23.4ms
# Speed: 8.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.17, Z 0.15, X 0.12, S 0.09, O 0.07, 14.4ms
# Speed: 8.1ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.21, R 0.16, Z 0.11, S 0.09, N 0.06, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.26, X 0.11, Z 0.10, S 0.09, N 0.06, 17.7ms
# Speed: 8.0ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.13, X 0.11, N 0.10, R 0.10, Q 0.09, 20.2ms
# Speed: 6.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.21, R 0.15, D 0.07, Q 0.07, X 0.06, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.36, O 0.09, D 0.07, Q 0.05, A 0.05, 14.2ms
# Speed: 8.2ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.61, D 0.06, X 0.04, O 0.04, U 0.03, 17.0ms
# Speed: 7.6ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.43, X 0.16, A 0.04, D 0.04, I 0.04, 20.0ms
# Speed: 6.4ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.49, X 0.06, A 0.06, I 0.04, D 0.04, 16.3ms
# Speed: 8.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.15, R 0.09, S 0.08, I 0.06, Z 0.06, 14.4ms
# Speed: 6.5ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.13, R 0.11, A 0.09, C 0.07, Z 0.06, 18.5ms
# Speed: 4.1ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.12, Z 0.12, A 0.10, N 0.08, M 0.06, 11.9ms
# Speed: 6.7ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.19, N 0.10, Z 0.09, A 0.08, T 0.07, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.17, Q 0.08, A 0.07, S 0.07, Z 0.07, 16.1ms
# Speed: 7.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.18, A 0.09, S 0.07, R 0.07, N 0.05, 13.3ms
# Speed: 7.7ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.14, Q 0.13, S 0.07, R 0.06, N 0.06, 18.5ms
# Speed: 5.4ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.14, S 0.10, A 0.09, R 0.08, X 0.05, 10.8ms
# Speed: 6.3ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.16, S 0.08, R 0.08, A 0.07, U 0.06, 16.5ms
# Speed: 8.5ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.12, A 0.10, R 0.08, S 0.07, C 0.07, 10.9ms
# Speed: 7.8ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.14, C 0.10, A 0.08, R 0.06, I 0.05, 14.6ms
# Speed: 13.5ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.15, C 0.09, R 0.09, O 0.07, S 0.06, 22.6ms
# Speed: 0.0ms preprocess, 22.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.14, C 0.10, A 0.07, S 0.07, U 0.06, 17.1ms
# Speed: 9.6ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.18, Q 0.16, A 0.09, O 0.07, S 0.06, 22.3ms
# Speed: 2.4ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.17, C 0.13, O 0.09, S 0.07, A 0.07, 18.7ms
# Speed: 7.6ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.17, C 0.12, O 0.09, U 0.07, S 0.06, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.13, Q 0.13, U 0.08, O 0.07, R 0.07, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, Q 0.12, O 0.07, R 0.06, S 0.06, 27.7ms
# Speed: 0.0ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.14, Q 0.13, R 0.11, O 0.08, U 0.07, 20.9ms
# Speed: 7.7ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.15, R 0.13, C 0.10, U 0.08, nothing 0.07, 20.5ms
# Speed: 8.3ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, Q 0.13, R 0.10, nothing 0.08, O 0.07, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.15, R 0.12, Q 0.11, O 0.07, nothing 0.07, 20.6ms
# Speed: 7.1ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, Q 0.11, R 0.10, O 0.09, U 0.07, 20.9ms
# Speed: 0.4ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.17, Q 0.10, O 0.09, R 0.08, nothing 0.07, 16.2ms
# Speed: 8.5ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.13, C 0.12, nothing 0.11, Q 0.09, O 0.07, 17.4ms
# Speed: 9.3ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.12, R 0.11, nothing 0.10, Q 0.09, O 0.08, 26.8ms
# Speed: 8.1ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.16, C 0.11, nothing 0.11, O 0.07, U 0.06, 16.3ms
# Speed: 8.4ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.17, C 0.10, O 0.09, nothing 0.08, Q 0.07, 21.5ms
# Speed: 4.6ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.16, C 0.12, O 0.10, Q 0.08, U 0.06, 19.7ms
# Speed: 8.5ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.13, C 0.11, O 0.09, Q 0.09, U 0.07, 20.4ms
# Speed: 5.6ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, R 0.10, O 0.10, Q 0.09, nothing 0.06, 21.8ms
# Speed: 8.6ms preprocess, 21.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.17, O 0.11, U 0.10, Q 0.09, C 0.07, 19.9ms
# Speed: 10.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.19, O 0.11, U 0.10, C 0.07, Q 0.06, 24.1ms
# Speed: 4.4ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.14, C 0.10, O 0.10, U 0.08, Q 0.08, 18.4ms
# Speed: 5.2ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.21, C 0.11, O 0.11, U 0.07, Q 0.07, 19.0ms
# Speed: 9.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.15, C 0.13, R 0.12, Q 0.07, S 0.06, 18.2ms
# Speed: 8.5ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.14, O 0.13, C 0.12, Q 0.09, S 0.07, 18.5ms
# Speed: 8.0ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.14, O 0.14, C 0.13, Q 0.07, S 0.07, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.23, O 0.12, C 0.07, S 0.07, E 0.07, 16.6ms
# Speed: 4.4ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.20, O 0.09, S 0.07, U 0.07, E 0.07, 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.12, O 0.10, C 0.10, S 0.08, U 0.07, 15.2ms
# Speed: 3.8ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.14, C 0.13, O 0.11, S 0.07, Q 0.06, 23.1ms
# Speed: 3.9ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.18, O 0.09, U 0.08, C 0.08, S 0.07, 19.5ms
# Speed: 0.0ms preprocess, 19.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.13, R 0.12, O 0.09, Q 0.09, S 0.07, 17.2ms
# Speed: 9.9ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.19, O 0.11, Q 0.08, S 0.08, R 0.06, 19.7ms
# Speed: 3.5ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.20, R 0.13, Q 0.10, O 0.08, S 0.07, 22.6ms
# Speed: 7.3ms preprocess, 22.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.17, R 0.15, O 0.12, S 0.08, Q 0.06, 16.1ms
# Speed: 5.3ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.20, R 0.10, O 0.10, S 0.08, Q 0.07, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.17, C 0.16, O 0.12, E 0.07, S 0.06, 15.2ms
# Speed: 8.1ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.21, C 0.14, O 0.08, S 0.06, E 0.05, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.22, R 0.12, O 0.10, Q 0.08, S 0.06, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.18, C 0.14, Q 0.08, S 0.08, O 0.08, 17.2ms
# Speed: 8.3ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.19, R 0.14, O 0.09, S 0.09, Q 0.06, 16.1ms
# Speed: 3.6ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.15, S 0.13, C 0.12, E 0.07, Q 0.07, 23.4ms
# Speed: 9.6ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.37, J 0.22, space 0.07, H 0.05, Y 0.05, 18.4ms
# Speed: 10.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.73, Y 0.09, X 0.05, I 0.03, A 0.03, 19.2ms
# Speed: 9.9ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.69, T 0.14, I 0.09, J 0.03, A 0.02, 17.3ms
# Speed: 7.6ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 15.9ms
# Speed: 4.0ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, I 0.00, X 0.00, 17.8ms
# Speed: 9.1ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, Y 0.00, T 0.00, X 0.00, L 0.00, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, X 0.00, I 0.00, 18.6ms
# Speed: 7.5ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.00, Y 0.00, I 0.00, L 0.00, 19.4ms
# Speed: 3.9ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, X 0.00, I 0.00, 15.9ms
# Speed: 8.5ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.97, T 0.03, Y 0.00, X 0.00, L 0.00, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.94, T 0.05, Y 0.00, X 0.00, L 0.00, 17.4ms
# Speed: 4.8ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.91, T 0.09, Y 0.00, L 0.00, X 0.00, 24.4ms
# Speed: 0.0ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.92, Y 0.04, T 0.03, L 0.01, I 0.00, 16.5ms
# Speed: 9.5ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.97, T 0.02, Y 0.01, L 0.00, I 0.00, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, L 0.00, Y 0.00, I 0.00, 18.8ms
# Speed: 6.2ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.00, L 0.00, Y 0.00, I 0.00, 16.6ms
# Speed: 9.2ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, L 0.00, Y 0.00, I 0.00, 12.7ms
# Speed: 7.5ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 18.2ms
# Speed: 10.0ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 16.1ms
# Speed: 6.7ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.00, Y 0.00, L 0.00, I 0.00, 16.3ms
# Speed: 5.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, L 0.00, Y 0.00, I 0.00, 15.4ms
# Speed: 8.4ms preprocess, 15.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 16.6ms
# Speed: 7.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.00, L 0.00, Y 0.00, I 0.00, 15.6ms
# Speed: 9.4ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 13.4ms
# Speed: 11.5ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 18.2ms
# Speed: 7.7ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 16.2ms
# Speed: 6.2ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 28.3ms
# Speed: 8.8ms preprocess, 28.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 18.5ms
# Speed: 5.5ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 21.2ms
# Speed: 9.5ms preprocess, 21.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 20.2ms
# Speed: 10.3ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 17.5ms
# Speed: 8.4ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 15.5ms
# Speed: 5.2ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.00, Y 0.00, L 0.00, X 0.00, 20.1ms
# Speed: 7.4ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, X 0.00, 16.3ms
# Speed: 5.6ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 16.9ms
# Speed: 8.1ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, I 0.00, 18.3ms
# Speed: 10.1ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, I 0.00, 27.3ms
# Speed: 0.0ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.00, Y 0.00, L 0.00, X 0.00, 15.8ms
# Speed: 10.2ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 15.8ms
# Speed: 8.5ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 26.4ms
# Speed: 0.0ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 11.9ms
# Speed: 10.1ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 16.9ms
# Speed: 8.5ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, I 0.00, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, I 0.00, 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 1.00, T 0.00, Y 0.00, L 0.00, X 0.00, 17.4ms
# Speed: 10.0ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, L 0.00, Y 0.00, X 0.00, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 18.7ms
# Speed: 7.3ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 18.6ms
# Speed: 8.2ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 23.7ms
# Speed: 0.0ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 20.0ms
# Speed: 4.6ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 16.4ms
# Speed: 7.4ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 16.1ms
# Speed: 7.9ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, X 0.00, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, Y 0.00, L 0.00, I 0.00, 22.4ms
# Speed: 9.1ms preprocess, 22.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.97, T 0.03, L 0.00, Y 0.00, X 0.00, 21.0ms
# Speed: 8.5ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.96, T 0.04, L 0.00, Y 0.00, X 0.00, 24.5ms
# Speed: 0.0ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.85, S 0.13, A 0.02, N 0.00, X 0.00, 21.9ms
# Speed: 7.9ms preprocess, 21.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.88, T 0.11, N 0.00, A 0.00, I 0.00, 18.1ms
# Speed: 9.5ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.99, T 0.00, A 0.00, I 0.00, N 0.00, 10.2ms
# Speed: 10.2ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, A 0.00, I 0.00, N 0.00, 16.9ms
# Speed: 7.4ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 19.0ms
# Speed: 9.8ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, A 0.00, 19.4ms
# Speed: 0.5ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, X 0.00, 12.3ms
# Speed: 5.9ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, E 0.00, 17.2ms
# Speed: 6.5ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, E 0.00, 20.1ms
# Speed: 5.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, E 0.00, 19.7ms
# Speed: 8.3ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.99, T 0.01, I 0.00, N 0.00, A 0.00, 15.5ms
# Speed: 7.9ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, E 0.00, 17.1ms
# Speed: 9.3ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, X 0.00, 27.2ms
# Speed: 0.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 19.1ms
# Speed: 7.0ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, A 0.00, I 0.00, N 0.00, 16.3ms
# Speed: 4.8ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, A 0.00, 12.9ms
# Speed: 8.2ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, E 0.00, 18.4ms
# Speed: 7.9ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, E 0.00, 30.4ms
# Speed: 0.0ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 23.1ms
# Speed: 2.7ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, A 0.00, I 0.00, N 0.00, 15.6ms
# Speed: 8.6ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.85, T 0.14, N 0.00, A 0.00, I 0.00, 26.3ms
# Speed: 0.0ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.52, S 0.47, A 0.01, N 0.00, X 0.00, 27.7ms
# Speed: 8.5ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.52, A 0.38, S 0.10, N 0.00, L 0.00, 20.5ms
# Speed: 4.2ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.62, T 0.37, S 0.00, L 0.00, Y 0.00, 18.9ms
# Speed: 7.9ms preprocess, 18.9ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.65, A 0.35, L 0.00, Y 0.00, S 0.00, 15.9ms
# Speed: 4.9ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.88, A 0.08, L 0.03, Y 0.01, S 0.00, 17.3ms
# Speed: 9.1ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.91, A 0.06, L 0.02, Y 0.01, S 0.00, 12.4ms
# Speed: 7.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.74, A 0.16, L 0.07, Y 0.03, S 0.00, 11.4ms
# Speed: 6.7ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.63, A 0.32, L 0.03, Y 0.02, S 0.00, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.66, A 0.32, Y 0.01, L 0.01, S 0.00, 13.9ms
# Speed: 7.3ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.54, T 0.43, Y 0.02, L 0.01, S 0.00, 20.4ms
# Speed: 4.8ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.48, T 0.47, Y 0.03, L 0.02, S 0.00, 19.0ms
# Speed: 7.5ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.56, A 0.40, Y 0.02, L 0.02, S 0.00, 19.6ms
# Speed: 5.6ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.58, T 0.40, Y 0.01, L 0.01, S 0.00, 17.2ms
# Speed: 7.8ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.50, T 0.44, Y 0.03, L 0.03, S 0.00, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.51, T 0.41, L 0.04, Y 0.03, S 0.00, 9.7ms
# Speed: 6.6ms preprocess, 9.7ms inference, 8.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.63, T 0.35, Y 0.01, L 0.01, S 0.00, 16.7ms
# Speed: 6.1ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.93, T 0.07, Y 0.00, L 0.00, S 0.00, 16.8ms
# Speed: 4.9ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.91, T 0.08, L 0.01, Y 0.00, I 0.00, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.95, T 0.05, L 0.00, Y 0.00, S 0.00, 17.8ms
# Speed: 7.7ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.87, T 0.13, S 0.00, L 0.00, Y 0.00, 12.4ms
# Speed: 6.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.67, A 0.30, S 0.03, X 0.00, N 0.00, 20.7ms
# Speed: 5.9ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.53, T 0.46, A 0.01, N 0.00, X 0.00, 26.3ms
# Speed: 0.0ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.98, T 0.02, X 0.00, I 0.00, N 0.00, 19.7ms
# Speed: 4.5ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, X 0.00, 19.7ms
# Speed: 7.0ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, X 0.00, 18.7ms
# Speed: 8.2ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, X 0.00, N 0.00, 23.3ms
# Speed: 2.7ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, X 0.00, 22.0ms
# Speed: 9.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 18.9ms
# Speed: 7.5ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 21.3ms
# Speed: 6.2ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, X 0.00, 19.6ms
# Speed: 9.9ms preprocess, 19.6ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, X 0.00, E 0.00, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, X 0.00, N 0.00, 15.6ms
# Speed: 8.2ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, N 0.00, A 0.00, 18.8ms
# Speed: 0.0ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, X 0.00, N 0.00, 18.1ms
# Speed: 8.1ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, X 0.00, N 0.00, 20.1ms
# Speed: 3.7ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, X 0.00, A 0.00, 14.5ms
# Speed: 6.4ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, X 0.00, 16.8ms
# Speed: 8.3ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, X 0.00, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 12.0ms
# Speed: 6.7ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, N 0.00, 19.4ms
# Speed: 0.0ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 1.00, T 0.00, I 0.00, A 0.00, X 0.00, 17.8ms
# Speed: 8.6ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.99, T 0.01, A 0.00, I 0.00, X 0.00, 18.9ms
# Speed: 7.9ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.82, T 0.17, A 0.01, N 0.00, X 0.00, 18.4ms
# Speed: 5.7ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.88, T 0.11, M 0.01, N 0.00, S 0.00, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 M 0.24, S 0.16, T 0.16, A 0.14, I 0.10, 19.4ms
# Speed: 8.0ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.22, X 0.10, A 0.09, R 0.08, C 0.07, 17.6ms
# Speed: 9.4ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, S 0.13, Q 0.08, R 0.07, X 0.06, 27.2ms
# Speed: 0.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.18, R 0.12, H 0.09, Q 0.08, S 0.06, 20.4ms
# Speed: 10.3ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.14, Q 0.11, R 0.11, H 0.08, S 0.07, 18.5ms
# Speed: 8.2ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.21, Q 0.11, R 0.08, H 0.08, S 0.07, 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.18, Q 0.13, S 0.08, R 0.07, H 0.06, 15.9ms
# Speed: 10.2ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.23, Q 0.11, R 0.07, S 0.07, H 0.06, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.27, Q 0.12, A 0.10, S 0.08, H 0.06, 19.7ms
# Speed: 3.2ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.19, Q 0.12, A 0.10, S 0.08, R 0.07, 19.0ms
# Speed: 8.5ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.20, Q 0.11, S 0.10, A 0.10, O 0.07, 21.8ms
# Speed: 9.8ms preprocess, 21.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.17, Q 0.15, R 0.08, S 0.07, A 0.07, 20.6ms
# Speed: 0.8ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.23, Q 0.15, O 0.09, S 0.07, R 0.06, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.20, Q 0.13, O 0.08, R 0.08, U 0.07, 20.3ms
# Speed: 10.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.24, Q 0.11, O 0.11, R 0.07, S 0.06, 12.6ms
# Speed: 8.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.15, Q 0.14, R 0.09, U 0.07, S 0.07, 14.2ms
# Speed: 7.4ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, Q 0.13, S 0.11, A 0.10, R 0.07, 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.16, Q 0.11, S 0.10, R 0.08, O 0.08, 11.1ms
# Speed: 7.3ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.14, C 0.13, R 0.09, S 0.08, O 0.07, 16.0ms
# Speed: 4.2ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.15, R 0.12, Q 0.08, S 0.07, O 0.07, 18.6ms
# Speed: 7.2ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.13, Q 0.11, S 0.08, R 0.08, A 0.07, 17.8ms
# Speed: 9.9ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.12, Q 0.10, C 0.10, S 0.08, U 0.06, 16.1ms
# Speed: 8.5ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.16, Q 0.10, C 0.09, S 0.07, U 0.06, 15.8ms
# Speed: 4.4ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.13, C 0.12, S 0.09, Q 0.08, A 0.06, 16.4ms
# Speed: 7.6ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.17, X 0.09, S 0.08, C 0.08, Q 0.07, 34.6ms
# Speed: 0.0ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.13, C 0.12, S 0.09, R 0.07, Q 0.07, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.12, S 0.11, A 0.10, R 0.09, X 0.07, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.12, Q 0.10, R 0.10, C 0.07, X 0.07, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.16, A 0.13, X 0.09, R 0.08, N 0.07, 18.6ms
# Speed: 3.8ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.17, X 0.11, N 0.10, A 0.09, R 0.08, 19.8ms
# Speed: 2.9ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.19, A 0.11, R 0.10, X 0.10, N 0.08, 14.9ms
# Speed: 0.7ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.18, S 0.17, R 0.14, A 0.06, N 0.05, 14.2ms
# Speed: 8.1ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.17, S 0.13, X 0.11, A 0.11, I 0.07, 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.27, X 0.19, S 0.09, E 0.06, I 0.05, 16.2ms
# Speed: 8.3ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 R 0.39, X 0.16, I 0.06, U 0.05, A 0.05, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Captured top class:  [0, 18, 19, 18]
# Translated text:  ['A', 'S', 'T', 'S']
# Confidence:  [tensor(0.9965), tensor(0.9950), tensor(0.9105), tensor(0.9997)]
