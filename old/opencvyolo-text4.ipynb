# %%
# Notes

# This version includes:

# capture interval, 
# confidence threshold, 
# capturing only different gestures (i.e., the current captured gesture must be different from the previous one).

# %%
# This code started as a direct copy from opencv
# https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html

import numpy as np
import cv2 as cv
import time

# Info about YOLO import and loading the Yolo Model
# https://docs.ultralytics.com/tasks/classify/#train

# Added this to import YOLO
from ultralytics import YOLO

# Load the YOLOv8 model, this is loading our custom-trained weights for our model.
model = YOLO("best_v2.pt")
 
cap = cv.VideoCapture(0)

captured_text = []
last_captured = None

# Set up Confidence Threshold
confidence_threshold = 0.5  # Set a confidence threshold

# Set up Capture interval
capture_interval = 1  # Time in seconds between capturing gestures

# Initialize time for the capture interval
last_capture_time = time.time()  # Time of the last capture

if not cap.isOpened():
    print("Cannot open camera")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
 
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

   
    # Set the size of the video
    ret = cap.set(cv.CAP_PROP_FRAME_WIDTH, 240)
    ret = cap.set(cv.CAP_PROP_FRAME_HEIGHT, 240)
    
    # Convert the frame to grayscale
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    
    # Display the grayscale frame
    cv.imshow('frame', gray)
    
    # Run YOLOv8 inference on the frame
    results = model(frame)
    top_class = results[0].probs.top1  # Get the most confident prediction
    top_confidence = results[0].probs.top1conf  # Get confidence of the top-class prediction

    # Check the time interval and confidence threshold before capturing
    current_time = time.time()
    if current_time - last_capture_time >= capture_interval:
        # Only capture if confidence is greater than threshold and gesture is new
        if top_confidence >= confidence_threshold and top_class != last_captured:
            captured_text.append(top_class)
            last_captured = top_class  # Update the last captured gesture
            last_capture_time = current_time  # Reset the capture time



    # Visualize the results on the frame
    annotated_frame = results[0].plot()

    # Display the annotated frame
    cv.imshow("YOLOv8 Inference", annotated_frame)

    # Exit when 'q' key is pressed
    if cv.waitKey(1) == ord('q'):
        print("Captured top class: ", captured_text)

        # ASCII reference to convert integer classes to text (A-Z, del, nothing, space)
        translated_text = []
        for i in captured_text:
            if i < 26:
                translated_text.append(chr(i + 65))  # A-Z
            elif i == 26:
                translated_text.append("del")
            elif i == 27:
                translated_text.append("nothing")
            elif i == 28:
                translated_text.append("space")
        
        print("Translated text: ", translated_text)
        break
        
# When everything is done, release the capture
cap.release()
cv.destroyAllWindows()
# Out:
# 0: 224x224 A 0.22, O 0.12, B 0.08, N 0.07, U 0.06, 40.3ms
# Speed: 9.6ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.23, D 0.19, F 0.14, C 0.11, K 0.07, 38.0ms
# Speed: 8.1ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.18, nothing 0.11, O 0.10, A 0.10, F 0.08, 31.0ms
# Speed: 5.8ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.22, K 0.18, C 0.10, D 0.07, N 0.06, 58.0ms
# Speed: 8.5ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.28, F 0.10, N 0.09, O 0.08, A 0.05, 48.2ms
# Speed: 6.1ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.25, N 0.11, O 0.10, M 0.07, F 0.06, 42.5ms
# Speed: 0.0ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.20, O 0.15, N 0.12, F 0.11, M 0.07, 46.9ms
# Speed: 5.5ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.16, K 0.15, M 0.11, F 0.10, A 0.06, 39.5ms
# Speed: 8.0ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.19, N 0.16, M 0.10, nothing 0.08, I 0.06, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.18, K 0.17, M 0.16, N 0.11, I 0.07, 32.5ms
# Speed: 5.3ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.24, M 0.17, N 0.13, K 0.12, I 0.06, 23.3ms
# Speed: 6.3ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.50, M 0.10, N 0.07, K 0.06, I 0.05, 43.0ms
# Speed: 0.3ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.61, M 0.07, I 0.05, K 0.05, N 0.04, 27.8ms
# Speed: 7.6ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.68, K 0.05, I 0.04, N 0.03, X 0.03, 28.5ms
# Speed: 7.6ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.96, del 0.01, Q 0.01, E 0.00, K 0.00, 25.4ms
# Speed: 6.8ms preprocess, 25.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.36, nothing 0.23, C 0.22, del 0.09, Q 0.06, 37.0ms
# Speed: 7.9ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.48, C 0.38, del 0.11, Q 0.02, S 0.00, 35.8ms
# Speed: 5.8ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.79, C 0.18, N 0.02, del 0.01, M 0.00, 48.2ms
# Speed: 7.9ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.36, O 0.36, del 0.13, S 0.05, N 0.04, 39.7ms
# Speed: 6.7ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.59, O 0.35, del 0.02, N 0.01, S 0.01, 33.6ms
# Speed: 8.3ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.61, O 0.34, N 0.02, del 0.01, S 0.01, 31.8ms
# Speed: 6.6ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.54, C 0.41, del 0.01, N 0.01, Q 0.01, 36.8ms
# Speed: 6.4ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.54, O 0.45, del 0.01, Q 0.00, N 0.00, 41.8ms
# Speed: 4.4ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.55, C 0.41, N 0.01, S 0.01, del 0.01, 36.8ms
# Speed: 11.4ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.46, O 0.33, del 0.09, Q 0.06, S 0.02, 35.6ms
# Speed: 5.3ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.32, N 0.19, S 0.14, del 0.13, M 0.05, 38.0ms
# Speed: 5.5ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.79, N 0.13, S 0.02, O 0.01, A 0.01, 50.5ms
# Speed: 0.0ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.24, N 0.15, del 0.12, X 0.11, S 0.09, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 J 0.29, X 0.21, I 0.17, G 0.12, N 0.06, 49.0ms
# Speed: 0.0ms preprocess, 49.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.30, I 0.12, J 0.12, O 0.11, M 0.09, 41.8ms
# Speed: 2.2ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.40, X 0.22, I 0.06, J 0.06, del 0.06, 42.7ms
# Speed: 0.0ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.33, N 0.22, X 0.18, J 0.06, S 0.05, 36.6ms
# Speed: 5.4ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.55, X 0.10, N 0.09, M 0.05, J 0.05, 27.4ms
# Speed: 8.3ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.25, J 0.24, X 0.23, I 0.10, N 0.05, 41.1ms
# Speed: 0.5ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.26, G 0.18, X 0.13, N 0.07, J 0.07, 23.9ms
# Speed: 4.5ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.19, N 0.17, M 0.11, X 0.09, G 0.09, 27.6ms
# Speed: 2.5ms preprocess, 27.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.38, F 0.33, Y 0.06, W 0.06, N 0.05, 25.1ms
# Speed: 5.5ms preprocess, 25.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.38, F 0.33, Y 0.06, W 0.06, N 0.05, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.35, F 0.29, nothing 0.18, K 0.07, B 0.03, 29.6ms
# Speed: 6.5ms preprocess, 29.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.49, F 0.28, nothing 0.08, K 0.06, N 0.02, 27.8ms
# Speed: 7.7ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.44, nothing 0.30, F 0.16, A 0.02, K 0.02, 31.7ms
# Speed: 4.4ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.51, W 0.25, nothing 0.13, A 0.03, K 0.03, 26.4ms
# Speed: 3.8ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.45, W 0.15, F 0.08, N 0.07, T 0.06, 23.6ms
# Speed: 6.0ms preprocess, 23.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.39, W 0.21, K 0.13, F 0.06, N 0.06, 23.4ms
# Speed: 2.5ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.35, nothing 0.20, F 0.14, K 0.12, T 0.07, 27.0ms
# Speed: 3.5ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.36, F 0.17, W 0.14, K 0.06, T 0.06, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.76, W 0.09, K 0.03, nothing 0.03, Y 0.03, 25.6ms
# Speed: 4.1ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.74, F 0.12, K 0.04, A 0.04, Y 0.01, 40.7ms
# Speed: 8.7ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.61, K 0.14, F 0.07, W 0.05, A 0.05, 37.1ms
# Speed: 4.7ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.29, K 0.22, nothing 0.22, A 0.09, I 0.04, 30.0ms
# Speed: 5.2ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.88, K 0.06, A 0.01, B 0.01, C 0.01, 30.5ms
# Speed: 5.4ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.38, O 0.11, X 0.09, C 0.07, Q 0.05, 22.3ms
# Speed: 11.1ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.29, S 0.25, G 0.10, nothing 0.09, X 0.05, 31.4ms
# Speed: 0.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.89, del 0.07, nothing 0.02, G 0.01, O 0.00, 27.1ms
# Speed: 8.2ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.96, del 0.03, G 0.00, O 0.00, nothing 0.00, 25.8ms
# Speed: 4.2ms preprocess, 25.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.60, C 0.20, del 0.06, A 0.03, Q 0.02, 22.8ms
# Speed: 1.5ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.85, C 0.04, G 0.03, del 0.03, A 0.01, 25.5ms
# Speed: 3.3ms preprocess, 25.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.57, C 0.12, G 0.08, del 0.05, K 0.03, 27.2ms
# Speed: 5.8ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.83, C 0.03, K 0.02, G 0.02, del 0.02, 27.6ms
# Speed: 6.3ms preprocess, 27.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.86, G 0.03, K 0.03, A 0.02, C 0.01, 25.2ms
# Speed: 5.3ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.83, G 0.05, K 0.02, del 0.02, C 0.01, 29.1ms
# Speed: 6.6ms preprocess, 29.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.73, G 0.06, K 0.04, C 0.03, A 0.03, 28.7ms
# Speed: 2.5ms preprocess, 28.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.36, nothing 0.34, G 0.14, Q 0.05, del 0.04, 29.3ms
# Speed: 8.6ms preprocess, 29.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.36, nothing 0.34, G 0.14, Q 0.05, del 0.04, 23.3ms
# Speed: 7.7ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.97, O 0.01, Q 0.00, S 0.00, N 0.00, 26.0ms
# Speed: 8.5ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.57, G 0.15, I 0.07, N 0.05, O 0.04, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.83, G 0.07, I 0.05, S 0.02, X 0.00, 25.7ms
# Speed: 9.2ms preprocess, 25.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.39, I 0.33, G 0.14, S 0.08, J 0.01, 25.2ms
# Speed: 9.3ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 I 0.36, G 0.29, S 0.17, nothing 0.09, J 0.03, 30.8ms
# Speed: 4.6ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.61, S 0.15, I 0.11, nothing 0.06, J 0.02, 50.4ms
# Speed: 6.3ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.77, I 0.09, S 0.06, nothing 0.04, X 0.01, 42.4ms
# Speed: 4.6ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.88, I 0.03, nothing 0.03, S 0.02, X 0.01, 37.3ms
# Speed: 0.0ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.86, I 0.03, nothing 0.03, S 0.02, N 0.01, 29.0ms
# Speed: 3.9ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.40, I 0.26, S 0.12, nothing 0.07, J 0.06, 33.0ms
# Speed: 6.4ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.61, I 0.17, S 0.06, nothing 0.06, N 0.02, 22.8ms
# Speed: 2.4ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.70, I 0.13, nothing 0.09, S 0.02, J 0.02, 28.9ms
# Speed: 4.1ms preprocess, 28.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.47, O 0.27, Q 0.23, G 0.01, N 0.01, 24.6ms
# Speed: 1.5ms preprocess, 24.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.48, del 0.45, Q 0.03, C 0.02, N 0.01, 40.6ms
# Speed: 8.0ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.58, del 0.35, C 0.05, Q 0.00, D 0.00, 37.5ms
# Speed: 10.9ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.89, O 0.06, C 0.03, Q 0.01, E 0.00, 32.8ms
# Speed: 0.0ms preprocess, 32.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.78, O 0.15, C 0.06, Q 0.00, D 0.00, 40.9ms
# Speed: 5.9ms preprocess, 40.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.63, O 0.30, C 0.06, Q 0.00, B 0.00, 36.0ms
# Speed: 5.8ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.45, del 0.44, C 0.11, Q 0.00, D 0.00, 40.7ms
# Speed: 7.8ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 O 0.96, C 0.02, del 0.01, D 0.00, Q 0.00, 36.4ms
# Speed: 3.6ms preprocess, 36.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.48, Q 0.25, O 0.19, D 0.03, C 0.01, 41.8ms
# Speed: 4.8ms preprocess, 41.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.72, N 0.06, O 0.04, X 0.04, Q 0.03, 23.7ms
# Speed: 1.1ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.34, N 0.29, X 0.14, S 0.06, K 0.04, 28.1ms
# Speed: 1.5ms preprocess, 28.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 I 0.23, A 0.14, X 0.13, S 0.10, nothing 0.10, 27.7ms
# Speed: 6.0ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.48, I 0.16, A 0.06, K 0.05, N 0.05, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.44, I 0.11, K 0.09, N 0.08, nothing 0.07, 33.2ms
# Speed: 8.8ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.44, I 0.11, K 0.09, N 0.08, nothing 0.07, 32.7ms
# Speed: 0.0ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.35, nothing 0.18, N 0.12, I 0.09, X 0.07, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.28, N 0.20, nothing 0.11, X 0.11, M 0.06, 34.7ms
# Speed: 7.5ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.26, X 0.22, N 0.20, I 0.06, nothing 0.06, 57.1ms
# Speed: 8.0ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.74, K 0.08, I 0.07, X 0.02, E 0.02, 36.7ms
# Speed: 6.0ms preprocess, 36.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.96, X 0.01, S 0.01, I 0.01, A 0.00, 28.8ms
# Speed: 3.9ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.96, Q 0.03, del 0.01, G 0.00, A 0.00, 36.0ms
# Speed: 7.2ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.45, del 0.33, Q 0.21, A 0.00, C 0.00, 35.3ms
# Speed: 9.2ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.53, Q 0.44, del 0.03, P 0.00, G 0.00, 17.9ms
# Speed: 6.7ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.51, nothing 0.42, del 0.06, P 0.00, Z 0.00, 33.1ms
# Speed: 8.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.72, del 0.14, nothing 0.10, X 0.01, N 0.01, 25.0ms
# Speed: 4.4ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.92, del 0.08, Z 0.00, P 0.00, nothing 0.00, 23.7ms
# Speed: 9.4ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.64, del 0.35, Z 0.00, P 0.00, nothing 0.00, 34.0ms
# Speed: 7.4ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.70, Q 0.27, Z 0.01, S 0.00, X 0.00, 31.7ms
# Speed: 9.3ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.37, del 0.30, nothing 0.21, X 0.02, S 0.02, 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Q 0.37, del 0.30, nothing 0.21, X 0.02, S 0.02, 31.6ms
# Speed: 5.4ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.73, Q 0.26, C 0.01, O 0.00, nothing 0.00, 23.9ms
# Speed: 5.6ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.97, Q 0.01, nothing 0.01, C 0.00, B 0.00, 25.3ms
# Speed: 5.3ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.77, C 0.14, Q 0.06, del 0.01, O 0.01, 33.4ms
# Speed: 0.0ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.96, C 0.02, Q 0.01, P 0.00, D 0.00, 33.8ms
# Speed: 8.1ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 1.00, N 0.00, Q 0.00, G 0.00, I 0.00, 28.9ms
# Speed: 7.1ms preprocess, 28.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.97, Q 0.02, C 0.00, P 0.00, N 0.00, 27.9ms
# Speed: 7.4ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.89, M 0.10, Q 0.01, A 0.00, nothing 0.00, 29.9ms
# Speed: 6.5ms preprocess, 29.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.79, M 0.20, A 0.00, T 0.00, nothing 0.00, 34.4ms
# Speed: 5.4ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.84, N 0.13, M 0.02, A 0.01, K 0.00, 48.4ms
# Speed: 0.0ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.53, nothing 0.38, M 0.07, A 0.01, K 0.00, 36.9ms
# Speed: 2.2ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.81, nothing 0.13, M 0.04, G 0.01, K 0.00, 32.0ms
# Speed: 2.6ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.88, nothing 0.06, M 0.05, A 0.00, K 0.00, 29.3ms
# Speed: 3.7ms preprocess, 29.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.78, nothing 0.15, M 0.05, A 0.01, T 0.00, 36.5ms
# Speed: 8.1ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.95, M 0.05, A 0.00, nothing 0.00, K 0.00, 35.2ms
# Speed: 5.9ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.95, M 0.05, A 0.00, nothing 0.00, K 0.00, 29.6ms
# Speed: 11.6ms preprocess, 29.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.96, M 0.03, nothing 0.00, A 0.00, K 0.00, 33.3ms
# Speed: 5.2ms preprocess, 33.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.96, M 0.03, nothing 0.00, A 0.00, K 0.00, 44.8ms
# Speed: 7.6ms preprocess, 44.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.59, M 0.41, A 0.00, nothing 0.00, T 0.00, 38.0ms
# Speed: 7.6ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.90, M 0.09, A 0.00, nothing 0.00, K 0.00, 33.5ms
# Speed: 8.5ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.90, M 0.09, A 0.00, nothing 0.00, K 0.00, 29.2ms
# Speed: 7.1ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.79, M 0.19, A 0.01, nothing 0.01, K 0.00, 30.9ms
# Speed: 5.1ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.63, M 0.34, A 0.01, nothing 0.01, T 0.00, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.90, M 0.08, A 0.01, nothing 0.00, K 0.00, 32.9ms
# Speed: 8.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.87, M 0.12, A 0.00, nothing 0.00, T 0.00, 41.3ms
# Speed: 5.2ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.55, M 0.29, nothing 0.12, A 0.03, K 0.00, 40.2ms
# Speed: 7.9ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.89, M 0.09, A 0.01, nothing 0.00, Y 0.00, 40.5ms
# Speed: 7.7ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.62, nothing 0.25, M 0.08, A 0.03, K 0.02, 33.6ms
# Speed: 8.1ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.80, A 0.13, N 0.02, K 0.02, B 0.01, 38.1ms
# Speed: 11.3ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.24, N 0.20, space 0.16, T 0.11, K 0.08, 36.0ms
# Speed: 7.2ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.49, T 0.33, A 0.08, S 0.03, K 0.02, 40.0ms
# Speed: 0.0ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.48, T 0.44, S 0.03, K 0.02, A 0.01, 24.0ms
# Speed: 5.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.50, T 0.18, S 0.08, A 0.06, K 0.04, 35.2ms
# Speed: 7.1ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.38, T 0.20, S 0.18, A 0.06, K 0.04, 34.3ms
# Speed: 8.0ms preprocess, 34.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.44, T 0.20, S 0.09, A 0.09, X 0.05, 25.2ms
# Speed: 6.3ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.28, N 0.26, T 0.17, S 0.11, nothing 0.06, 33.1ms
# Speed: 7.9ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.74, T 0.09, A 0.08, S 0.04, X 0.01, 30.9ms
# Speed: 9.6ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.46, A 0.13, K 0.10, S 0.07, X 0.07, 42.1ms
# Speed: 7.2ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.80, A 0.11, N 0.02, C 0.02, K 0.01, 33.2ms
# Speed: 8.5ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.97, A 0.03, B 0.00, K 0.00, C 0.00, 46.7ms
# Speed: 1.0ms preprocess, 46.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 M 0.59, N 0.37, nothing 0.03, A 0.01, S 0.00, 31.5ms
# Speed: 5.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.64, M 0.13, N 0.08, Q 0.04, S 0.03, 40.4ms
# Speed: 8.7ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.90, del 0.03, Q 0.03, S 0.01, M 0.01, 35.2ms
# Speed: 7.5ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.76, del 0.08, Q 0.05, I 0.02, S 0.02, 33.1ms
# Speed: 7.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.36, I 0.28, J 0.16, nothing 0.10, C 0.03, 27.8ms
# Speed: 8.3ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 I 0.48, S 0.27, del 0.15, J 0.06, nothing 0.03, 32.7ms
# Speed: 0.0ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.78, del 0.11, Q 0.06, G 0.01, C 0.01, 34.6ms
# Speed: 6.9ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.78, del 0.11, Q 0.06, G 0.01, C 0.01, 40.5ms
# Speed: 8.5ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.86, Q 0.09, del 0.03, A 0.01, S 0.00, 39.5ms
# Speed: 8.3ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.98, Q 0.00, del 0.00, A 0.00, C 0.00, 32.1ms
# Speed: 8.2ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 1.00, Q 0.00, I 0.00, S 0.00, K 0.00, 27.0ms
# Speed: 8.5ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.90, I 0.03, J 0.01, G 0.01, C 0.01, 31.2ms
# Speed: 5.7ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.85, Q 0.03, del 0.02, I 0.02, G 0.01, 26.5ms
# Speed: 8.0ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.97, Q 0.01, del 0.00, I 0.00, K 0.00, 41.7ms
# Speed: 0.0ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 1.00, Q 0.00, del 0.00, K 0.00, C 0.00, 30.5ms
# Speed: 8.3ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.95, C 0.01, del 0.01, Q 0.01, G 0.01, 36.9ms
# Speed: 4.7ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 del 0.45, nothing 0.24, Q 0.21, O 0.04, C 0.01, 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.37, M 0.25, N 0.24, S 0.02, O 0.02, 50.9ms
# Speed: 8.5ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.51, N 0.21, M 0.14, S 0.02, V 0.02, 32.2ms
# Speed: 7.7ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.40, M 0.25, W 0.21, S 0.02, O 0.02, 32.5ms
# Speed: 5.9ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.33, W 0.25, M 0.23, T 0.04, O 0.04, 33.2ms
# Speed: 3.6ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.44, M 0.40, W 0.09, I 0.01, S 0.01, 36.3ms
# Speed: 4.9ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 M 0.46, N 0.35, W 0.10, S 0.01, K 0.01, 32.6ms
# Speed: 9.6ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.40, M 0.34, W 0.10, S 0.04, O 0.02, 32.9ms
# Speed: 0.6ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 M 0.27, N 0.26, W 0.20, S 0.06, O 0.04, 38.8ms
# Speed: 8.3ms preprocess, 38.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.31, N 0.20, M 0.18, S 0.05, V 0.05, 24.9ms
# Speed: 8.5ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.39, M 0.30, N 0.15, S 0.02, K 0.02, 41.2ms
# Speed: 8.1ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.42, M 0.12, nothing 0.07, I 0.05, O 0.05, 32.4ms
# Speed: 8.0ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.38, M 0.14, O 0.07, S 0.05, U 0.05, 32.4ms
# Speed: 8.1ms preprocess, 32.4ms inference, 5.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.32, M 0.09, U 0.07, W 0.07, nothing 0.06, 54.5ms
# Speed: 6.1ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.28, S 0.22, M 0.08, nothing 0.06, I 0.05, 40.6ms
# Speed: 8.1ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.39, M 0.14, nothing 0.08, K 0.07, W 0.06, 42.7ms
# Speed: 5.2ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.21, nothing 0.14, W 0.12, K 0.08, S 0.05, 33.1ms
# Speed: 7.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.25, S 0.12, M 0.09, nothing 0.08, W 0.08, 41.4ms
# Speed: 8.1ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.31, M 0.11, S 0.08, nothing 0.07, I 0.06, 29.2ms
# Speed: 4.4ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.34, M 0.13, K 0.09, nothing 0.08, B 0.05, 30.9ms
# Speed: 5.7ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.18, K 0.14, W 0.12, M 0.10, nothing 0.08, 32.5ms
# Speed: 3.3ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.18, K 0.14, W 0.12, M 0.10, nothing 0.08, 32.9ms
# Speed: 3.5ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.48, K 0.10, N 0.09, M 0.05, W 0.04, 30.4ms
# Speed: 4.4ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.27, N 0.13, K 0.13, W 0.07, X 0.05, 32.5ms
# Speed: 8.9ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.25, nothing 0.22, K 0.09, M 0.08, S 0.06, 26.7ms
# Speed: 10.9ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.32, M 0.23, N 0.16, K 0.10, V 0.04, 34.3ms
# Speed: 4.0ms preprocess, 34.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 W 0.32, M 0.23, N 0.16, K 0.10, V 0.04, 42.0ms
# Speed: 2.7ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 K 0.33, nothing 0.15, N 0.09, T 0.06, X 0.05, 50.9ms
# Speed: 0.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nothing 0.47, N 0.15, K 0.09, M 0.06, W 0.04, 34.0ms
# Speed: 8.2ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Captured top class:  [27, 2, 6, 5, 27, 6, 14, 27, 13, 27, 12, 27]
# Translated text:  ['nothing', 'C', 'G', 'F', 'nothing', 'G', 'O', 'nothing', 'N', 'nothing', 'M', 'nothing']
