# %%
# This code started as a direct copy from opencv
# https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html

import numpy as np
import cv2 as cv

# Info about YOLO import and loading the Yolo Model
# https://docs.ultralytics.com/tasks/classify/#train

# Added this to import YOLO
from ultralytics import YOLO

# Load the YOLOv8 model, this is loading our custom trained weights for our model.
model = YOLO("best_v2.pt")
 
cap = cv.VideoCapture(0)

captured_text = []
captured_confidence = []
confidence_requirement = 0.75
count = 1
last = None

if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
 
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    
    # These two lines are found here https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html
    # They reduce the size of the video
    
    ret = cap.set(cv.CAP_PROP_FRAME_WIDTH,240)
    ret = cap.set(cv.CAP_PROP_FRAME_HEIGHT,240)
    
    # Our operations on the frame come here
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    # Display the resulting frame
    cv.imshow('frame', gray)
    
    # If you scroll to the very bottom of this link
    # https://docs.ultralytics.com/modes/predict/#thread-safe-inference
    # You will find the next 3 lines of code which I took from their and applied to this similar example
    
    # Run YOLOv8 inference on the frame
    results = model(frame)
    top_class = results[0].probs.top1
    top_confidence = results[0].probs.top1conf  # Get confidence of the top-class prediction
    
    if (top_confidence >= confidence_requirement):
        
        if (top_class == last):
            
            count=count+1
            
            if ((count>=4) and (appended==False)):
            
                captured_text.append(top_class)
                captured_confidence.append(top_confidence)
                appended=True
                
        else:
            count=1
            appended=False
                
        last = top_class
    
    # Visualize the results on the frame
    annotated_frame = results[0].plot()
    
    
    # Display the annotated frame
    cv.imshow("YOLOv8 Inference", annotated_frame)
    
    
    
    if cv.waitKey(1) == ord('q'):
        print("Captured top class: ", captured_text)
        
        # ASCII ref
        #https://simple.m.wikipedia.org/wiki/File:ASCII-Table-wide.svg
        
        # https://stackoverflow.com/questions/3673428/convert-int-to-ascii-and-back-in-python
        # Integer to ASCII
        
        translated_text = []
        for i in captured_text:
            
            if i<26:
                translated_text.append(chr(i+65))
            elif i==26:
                translated_text.append("del")
            elif i==27:
                translated_text.append("nothing")
            elif i==28:
                translated_text.append("space")
        
        for i in range(len(translated_text)):
            
            translated_text[i] = (translated_text[i], captured_confidence[i].item())
        
        print("Translated text: ", translated_text)
        break
        
        
 
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()
# Out:
# 0: 224x224 G 0.17, M 0.12, Y 0.11, N 0.09, E 0.08, 22.1ms
# Speed: 25.7ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.10, U 0.09, S 0.08, X 0.07, V 0.06, 7.3ms
# Speed: 4.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.10, U 0.10, S 0.08, V 0.07, W 0.06, 6.4ms
# Speed: 4.6ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.10, U 0.09, S 0.08, W 0.07, V 0.07, 6.9ms
# Speed: 3.9ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.12, U 0.08, W 0.08, V 0.06, S 0.06, 7.2ms
# Speed: 4.6ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.10, U 0.09, S 0.07, W 0.07, V 0.07, 11.0ms
# Speed: 6.2ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.13, U 0.08, W 0.07, Y 0.06, V 0.06, 17.8ms
# Speed: 8.5ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.11, U 0.10, W 0.07, X 0.07, S 0.06, 11.4ms
# Speed: 6.5ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.10, X 0.10, S 0.10, G 0.09, W 0.06, 6.8ms
# Speed: 5.2ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.13, X 0.11, G 0.10, U 0.09, I 0.05, 6.1ms
# Speed: 5.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.11, G 0.09, S 0.07, X 0.07, W 0.07, 7.5ms
# Speed: 5.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.11, G 0.10, S 0.08, X 0.08, W 0.07, 6.0ms
# Speed: 5.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.10, G 0.10, S 0.08, X 0.07, W 0.06, 7.8ms
# Speed: 5.9ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.09, U 0.09, S 0.09, X 0.09, M 0.08, 7.6ms
# Speed: 5.1ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.09, U 0.09, G 0.09, M 0.08, S 0.07, 7.4ms
# Speed: 5.1ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.10, X 0.10, G 0.09, S 0.08, M 0.07, 7.0ms
# Speed: 6.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.13, S 0.11, T 0.10, N 0.07, U 0.07, 6.5ms
# Speed: 5.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.36, G 0.33, I 0.04, L 0.03, W 0.03, 7.2ms
# Speed: 5.4ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.97, L 0.02, G 0.01, T 0.00, W 0.00, 6.3ms
# Speed: 5.8ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.87, L 0.07, T 0.03, W 0.01, G 0.01, 8.0ms
# Speed: 5.9ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.93, L 0.02, H 0.01, G 0.01, A 0.01, 8.1ms
# Speed: 5.3ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.99, A 0.00, I 0.00, T 0.00, J 0.00, 6.9ms
# Speed: 5.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.45, E 0.24, S 0.14, T 0.05, Y 0.04, 6.6ms
# Speed: 5.7ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.49, T 0.14, A 0.10, M 0.09, N 0.08, 6.1ms
# Speed: 5.3ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 N 0.24, T 0.20, M 0.17, A 0.13, E 0.12, 8.3ms
# Speed: 5.5ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.43, A 0.21, S 0.10, N 0.10, M 0.08, 9.5ms
# Speed: 5.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.41, S 0.26, A 0.18, N 0.06, M 0.04, 7.6ms
# Speed: 6.1ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.36, A 0.34, S 0.27, E 0.01, N 0.01, 8.3ms
# Speed: 6.2ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.54, T 0.25, S 0.21, N 0.00, E 0.00, 9.1ms
# Speed: 6.7ms preprocess, 9.1ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.53, S 0.30, T 0.17, L 0.00, I 0.00, 7.3ms
# Speed: 6.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.63, S 0.28, T 0.09, L 0.00, N 0.00, 7.9ms
# Speed: 6.3ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.91, T 0.06, S 0.03, L 0.00, N 0.00, 9.8ms
# Speed: 6.4ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.97, T 0.02, S 0.00, L 0.00, I 0.00, 8.0ms
# Speed: 4.9ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.95, T 0.04, S 0.01, N 0.00, I 0.00, 8.9ms
# Speed: 6.5ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.98, T 0.02, S 0.00, N 0.00, L 0.00, 6.5ms
# Speed: 5.9ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.98, T 0.02, S 0.00, N 0.00, Y 0.00, 7.3ms
# Speed: 5.3ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.91, T 0.09, S 0.01, N 0.00, I 0.00, 8.2ms
# Speed: 5.8ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.93, T 0.07, S 0.00, N 0.00, Y 0.00, 6.8ms
# Speed: 5.9ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.93, T 0.07, S 0.01, N 0.00, I 0.00, 6.4ms
# Speed: 5.3ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.96, T 0.03, S 0.00, N 0.00, I 0.00, 6.4ms
# Speed: 6.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.96, T 0.03, S 0.00, N 0.00, I 0.00, 8.4ms
# Speed: 6.3ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.95, T 0.04, S 0.00, N 0.00, I 0.00, 6.2ms
# Speed: 4.9ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.95, T 0.05, S 0.00, N 0.00, I 0.00, 9.7ms
# Speed: 6.5ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.95, T 0.05, S 0.00, N 0.00, I 0.00, 6.2ms
# Speed: 5.4ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.94, T 0.05, S 0.00, N 0.00, I 0.00, 8.5ms
# Speed: 5.2ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, S 0.00, N 0.00, I 0.00, 6.2ms
# Speed: 6.2ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.99, T 0.01, S 0.00, N 0.00, I 0.00, 9.1ms
# Speed: 5.9ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.96, T 0.04, S 0.00, N 0.00, I 0.00, 8.4ms
# Speed: 5.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 A 0.96, T 0.03, S 0.01, N 0.00, M 0.00, 9.8ms
# Speed: 5.7ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.38, A 0.26, N 0.20, M 0.11, S 0.03, 7.7ms
# Speed: 5.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.80, B 0.10, A 0.04, I 0.01, M 0.01, 7.1ms
# Speed: 6.2ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.92, E 0.07, F 0.00, M 0.00, W 0.00, 7.6ms
# Speed: 5.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 1.00, F 0.00, E 0.00, W 0.00, N 0.00, 6.6ms
# Speed: 4.9ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, W 0.00, E 0.00, U 0.00, 6.7ms
# Speed: 6.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, E 0.00, W 0.00, U 0.00, 8.4ms
# Speed: 6.1ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.98, F 0.02, E 0.00, W 0.00, U 0.00, 7.1ms
# Speed: 6.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.98, F 0.02, E 0.00, W 0.00, U 0.00, 7.6ms
# Speed: 6.1ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, W 0.00, E 0.00, U 0.00, 7.6ms
# Speed: 5.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, E 0.00, W 0.00, U 0.00, 6.8ms
# Speed: 6.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, E 0.00, U 0.00, W 0.00, 9.3ms
# Speed: 6.4ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, E 0.00, U 0.00, N 0.00, 8.0ms
# Speed: 5.1ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, U 0.00, E 0.00, W 0.00, 9.1ms
# Speed: 5.2ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 B 0.99, F 0.01, E 0.00, U 0.00, W 0.00, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 T 0.33, C 0.28, G 0.10, F 0.07, H 0.05, 7.8ms
# Speed: 5.4ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.86, G 0.07, C 0.05, Y 0.01, P 0.00, 7.0ms
# Speed: 5.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.99, L 0.01, G 0.00, Y 0.00, Q 0.00, 6.9ms
# Speed: 5.0ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, Q 0.00, 9.4ms
# Speed: 6.8ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 6.8ms
# Speed: 6.3ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, G 0.00, L 0.00, Y 0.00, F 0.00, 8.9ms
# Speed: 6.7ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, Q 0.00, 7.3ms
# Speed: 6.9ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, G 0.00, L 0.00, Y 0.00, F 0.00, 6.7ms
# Speed: 5.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 10.1ms
# Speed: 6.2ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, Q 0.00, 8.0ms
# Speed: 5.6ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, Q 0.00, 7.8ms
# Speed: 6.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, Q 0.00, 7.5ms
# Speed: 5.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, G 0.00, L 0.00, F 0.00, Y 0.00, 6.6ms
# Speed: 5.1ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 6.8ms
# Speed: 5.6ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, F 0.00, Y 0.00, 7.9ms
# Speed: 5.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 8.6ms
# Speed: 5.7ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 7.3ms
# Speed: 5.3ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 8.5ms
# Speed: 5.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, F 0.00, Y 0.00, 6.6ms
# Speed: 5.7ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, F 0.00, Y 0.00, 6.7ms
# Speed: 5.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 1.00, L 0.00, G 0.00, Y 0.00, F 0.00, 7.5ms
# Speed: 5.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 C 0.95, G 0.02, L 0.01, Y 0.01, P 0.00, 6.2ms
# Speed: 5.1ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.38, T 0.22, I 0.12, E 0.10, Y 0.06, 6.8ms
# Speed: 5.1ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.61, I 0.23, M 0.06, Y 0.03, N 0.02, 6.8ms
# Speed: 5.7ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.96, M 0.02, I 0.01, N 0.00, D 0.00, 8.9ms
# Speed: 5.7ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.72, M 0.21, I 0.05, N 0.02, D 0.00, 7.8ms
# Speed: 5.3ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.83, M 0.10, I 0.05, N 0.01, D 0.00, 7.6ms
# Speed: 5.6ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.82, M 0.12, N 0.03, I 0.02, D 0.00, 8.3ms
# Speed: 5.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.71, M 0.23, I 0.04, N 0.02, D 0.00, 7.3ms
# Speed: 5.4ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.67, M 0.17, I 0.12, N 0.03, D 0.01, 7.9ms
# Speed: 5.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.69, M 0.15, I 0.11, N 0.02, D 0.01, 9.1ms
# Speed: 5.2ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.70, M 0.18, I 0.08, N 0.02, D 0.01, 8.3ms
# Speed: 5.7ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.76, M 0.17, I 0.04, N 0.01, D 0.01, 7.5ms
# Speed: 4.8ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.69, M 0.19, I 0.08, N 0.02, D 0.01, 9.5ms
# Speed: 4.9ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.53, M 0.37, I 0.06, N 0.02, D 0.00, 8.2ms
# Speed: 6.3ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.53, M 0.31, I 0.09, N 0.04, D 0.02, 7.6ms
# Speed: 5.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.32, M 0.31, N 0.23, I 0.07, T 0.03, 8.2ms
# Speed: 5.6ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.99, G 0.00, D 0.00, F 0.00, I 0.00, 7.7ms
# Speed: 6.3ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.28, S 0.20, I 0.14, M 0.13, N 0.08, 8.7ms
# Speed: 6.4ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 X 0.28, M 0.21, N 0.15, S 0.11, E 0.09, 8.0ms
# Speed: 5.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.20, N 0.18, M 0.17, E 0.15, X 0.11, 8.1ms
# Speed: 5.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 D 0.34, E 0.24, I 0.10, V 0.08, F 0.05, 7.2ms
# Speed: 5.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 D 0.43, X 0.22, U 0.10, I 0.09, V 0.08, 7.0ms
# Speed: 4.8ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.95, F 0.03, V 0.01, D 0.00, X 0.00, 7.7ms
# Speed: 5.3ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.86, U 0.08, V 0.04, D 0.01, K 0.00, 7.1ms
# Speed: 6.2ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.91, U 0.05, V 0.02, T 0.01, B 0.00, 7.8ms
# Speed: 5.3ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.97, W 0.01, D 0.00, B 0.00, T 0.00, 7.2ms
# Speed: 5.4ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.99, T 0.00, B 0.00, W 0.00, E 0.00, 9.0ms
# Speed: 6.2ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.99, B 0.00, T 0.00, W 0.00, D 0.00, 6.8ms
# Speed: 6.2ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 1.00, B 0.00, W 0.00, T 0.00, D 0.00, 7.0ms
# Speed: 5.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.99, W 0.00, T 0.00, E 0.00, B 0.00, 8.3ms
# Speed: 6.2ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.95, W 0.02, D 0.01, V 0.01, E 0.00, 6.6ms
# Speed: 5.3ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.97, W 0.01, D 0.01, V 0.00, T 0.00, 8.9ms
# Speed: 5.3ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.88, V 0.04, D 0.03, E 0.01, W 0.01, 7.0ms
# Speed: 6.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.93, D 0.02, V 0.01, E 0.01, T 0.01, 6.6ms
# Speed: 6.3ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.93, D 0.03, E 0.02, V 0.01, T 0.01, 6.8ms
# Speed: 5.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.88, D 0.05, V 0.02, E 0.02, W 0.01, 7.4ms
# Speed: 6.1ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 F 0.91, D 0.04, V 0.02, E 0.01, T 0.01, 7.7ms
# Speed: 5.1ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 E 0.91, I 0.06, D 0.02, F 0.01, X 0.00, 10.1ms
# Speed: 6.7ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 M 0.17, N 0.16, O 0.15, E 0.10, X 0.07, 11.8ms
# Speed: 7.2ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.70, L 0.10, Y 0.08, P 0.03, H 0.02, 7.3ms
# Speed: 6.1ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.78, P 0.10, L 0.10, Y 0.02, H 0.00, 7.7ms
# Speed: 5.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.71, P 0.17, L 0.07, Y 0.04, H 0.00, 8.6ms
# Speed: 5.9ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.67, P 0.12, L 0.12, Y 0.07, Q 0.00, 8.3ms
# Speed: 5.1ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.87, L 0.06, P 0.05, Y 0.01, H 0.00, 10.6ms
# Speed: 6.8ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.94, P 0.05, L 0.01, Y 0.00, H 0.00, 7.5ms
# Speed: 6.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.99, P 0.01, H 0.00, L 0.00, Y 0.00, 8.5ms
# Speed: 6.7ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.99, P 0.01, H 0.00, L 0.00, C 0.00, 7.3ms
# Speed: 5.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 1.00, P 0.00, H 0.00, C 0.00, D 0.00, 6.2ms
# Speed: 5.2ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 1.00, P 0.00, H 0.00, D 0.00, C 0.00, 8.7ms
# Speed: 6.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 1.00, P 0.00, H 0.00, D 0.00, C 0.00, 8.6ms
# Speed: 6.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 1.00, P 0.00, H 0.00, D 0.00, C 0.00, 9.0ms
# Speed: 5.3ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.88, G 0.12, C 0.00, A 0.00, P 0.00, 9.3ms
# Speed: 6.2ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.94, G 0.06, C 0.00, A 0.00, F 0.00, 6.5ms
# Speed: 5.4ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.93, G 0.07, C 0.00, A 0.00, F 0.00, 8.7ms
# Speed: 6.2ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.97, G 0.03, C 0.00, A 0.00, P 0.00, 6.6ms
# Speed: 5.4ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.92, G 0.08, C 0.00, P 0.00, A 0.00, 7.0ms
# Speed: 4.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.96, G 0.04, C 0.00, A 0.00, P 0.00, 7.1ms
# Speed: 4.9ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.90, G 0.10, C 0.00, P 0.00, A 0.00, 10.6ms
# Speed: 6.4ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.88, G 0.12, C 0.00, P 0.00, F 0.00, 7.3ms
# Speed: 5.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.74, G 0.26, C 0.00, P 0.00, F 0.00, 7.6ms
# Speed: 5.7ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.57, H 0.43, C 0.00, P 0.00, F 0.00, 6.5ms
# Speed: 5.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.57, H 0.43, C 0.00, P 0.00, F 0.00, 6.8ms
# Speed: 5.3ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.71, G 0.29, C 0.00, P 0.00, F 0.00, 7.3ms
# Speed: 5.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.85, G 0.15, C 0.00, P 0.00, F 0.00, 6.8ms
# Speed: 5.5ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.74, G 0.26, C 0.00, P 0.00, F 0.00, 6.8ms
# Speed: 5.3ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.71, G 0.29, C 0.00, P 0.00, F 0.00, 7.6ms
# Speed: 5.5ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.53, G 0.47, C 0.00, P 0.00, F 0.00, 8.4ms
# Speed: 6.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.80, H 0.20, C 0.00, P 0.00, F 0.00, 6.3ms
# Speed: 4.9ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.86, H 0.14, C 0.00, P 0.00, F 0.00, 6.3ms
# Speed: 6.3ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.72, H 0.28, C 0.00, P 0.00, F 0.00, 8.6ms
# Speed: 5.3ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.84, H 0.16, C 0.00, P 0.00, F 0.00, 7.5ms
# Speed: 6.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.62, H 0.38, C 0.00, P 0.00, F 0.00, 7.4ms
# Speed: 6.4ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.55, H 0.45, C 0.00, P 0.00, F 0.00, 7.3ms
# Speed: 5.3ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.69, H 0.30, C 0.00, P 0.00, A 0.00, 7.4ms
# Speed: 5.4ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.60, H 0.40, C 0.00, P 0.00, F 0.00, 7.3ms
# Speed: 5.2ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.68, H 0.32, C 0.00, P 0.00, F 0.00, 6.7ms
# Speed: 5.4ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.62, H 0.38, C 0.00, P 0.00, F 0.00, 7.1ms
# Speed: 5.2ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.68, H 0.32, C 0.00, P 0.00, F 0.00, 8.2ms
# Speed: 5.4ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.78, H 0.22, C 0.00, P 0.00, F 0.00, 7.7ms
# Speed: 6.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.83, H 0.17, C 0.00, P 0.00, F 0.00, 6.0ms
# Speed: 6.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.84, H 0.16, C 0.00, P 0.00, F 0.00, 6.9ms
# Speed: 5.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.85, H 0.14, C 0.00, P 0.00, F 0.00, 7.0ms
# Speed: 4.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.77, H 0.23, C 0.00, P 0.00, F 0.00, 9.6ms
# Speed: 6.3ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.89, H 0.11, C 0.00, F 0.00, P 0.00, 6.0ms
# Speed: 5.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.71, H 0.29, C 0.00, P 0.00, F 0.00, 9.0ms
# Speed: 5.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.76, H 0.24, C 0.00, F 0.00, A 0.00, 8.4ms
# Speed: 5.3ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.54, H 0.46, C 0.00, F 0.00, P 0.00, 10.1ms
# Speed: 6.1ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 G 0.58, H 0.42, C 0.00, P 0.00, F 0.00, 6.6ms
# Speed: 5.0ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 H 0.92, G 0.08, C 0.00, A 0.00, F 0.00, 6.6ms
# Speed: 5.5ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.57, T 0.28, L 0.10, W 0.02, V 0.01, 8.3ms
# Speed: 6.5ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, Y 0.00, T 0.00, G 0.00, V 0.00, 6.1ms
# Speed: 4.8ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.98, Y 0.00, V 0.00, C 0.00, space 0.00, 7.7ms
# Speed: 5.6ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.98, V 0.01, Y 0.01, P 0.00, N 0.00, 6.4ms
# Speed: 5.9ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.98, V 0.02, Y 0.00, W 0.00, D 0.00, 9.3ms
# Speed: 5.5ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.99, V 0.01, Y 0.00, D 0.00, Q 0.00, 6.7ms
# Speed: 5.1ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, R 0.00, 6.6ms
# Speed: 6.0ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, B 0.00, 8.4ms
# Speed: 5.5ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.99, V 0.00, D 0.00, Y 0.00, X 0.00, 6.3ms
# Speed: 5.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, X 0.00, 8.3ms
# Speed: 5.6ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, X 0.00, 6.1ms
# Speed: 4.9ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, X 0.00, 8.8ms
# Speed: 5.2ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, C 0.00, 7.1ms
# Speed: 6.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, C 0.00, 6.3ms
# Speed: 5.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, Y 0.00, D 0.00, X 0.00, 8.4ms
# Speed: 6.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, Y 0.00, D 0.00, X 0.00, 8.4ms
# Speed: 6.4ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 0.99, V 0.00, D 0.00, Y 0.00, X 0.00, 7.3ms
# Speed: 4.9ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, D 0.00, Y 0.00, X 0.00, 7.5ms
# Speed: 5.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, Y 0.00, D 0.00, C 0.00, 8.1ms
# Speed: 5.4ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 L 1.00, V 0.00, Y 0.00, space 0.00, W 0.00, 9.2ms
# Speed: 6.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Y 0.43, L 0.13, T 0.06, N 0.05, G 0.04, 7.2ms
# Speed: 5.8ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 U 0.10, X 0.09, S 0.08, M 0.08, G 0.08, 7.1ms
# Speed: 5.7ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 S 0.10, U 0.09, G 0.08, X 0.08, W 0.08, 7.1ms
# Speed: 5.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 M 0.10, U 0.09, X 0.09, S 0.08, G 0.08, 7.1ms
# Speed: 5.1ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Captured top class:  [24, 0, 1, 2, 4, 5, 6, 7, 6, 11]
# Translated text:  [('Y', 0.9867720007896423), ('A', 0.9786292314529419), ('B', 0.9887079000473022), ('C', 0.9992457628250122), ('E', 0.7584028244018555), ('F', 0.9897918701171875), ('G', 0.9877102375030518), ('H', 0.9733737707138062), ('G', 0.7795118689537048), ('L', 0.9803378582000732)]
